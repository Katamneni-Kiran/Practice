# %% [markdown]
# # Import required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib as mtl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Check the version of each library

# %%
print("version of pandas: ", pd.__version__)
print("version of numpy: ", np.__version__)
print("version of matplotlib: ", mtl.__version__)
print("version of seaborn: ", sns.__version__)
# Out:
# version of pandas:  1.0.5
# version of numpy:  1.18.5
# version of matplotlib:  3.2.2
# version of seaborn:  0.10.1

# %% [markdown]
# # Read the data using pandas

# %%
heart = pd.read_csv("heart.csv")
print("Done successfully!")
# Out:
# Done successfully!

# %%
heart.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %% [markdown]
#     1.Age : Age of the patient
#     2.Sex : Sex of the patient
#     3.exng: exercise induced angina (1 = yes; 0 = no)
#     4.ca: number of major vessels (0-3)
#     5.cp : Chest Pain type chest pain type
#         Value 0: typical angina
#         Value 1: atypical angina
#         Value 2: non-anginal pain
#         Value 3: asymptomatic
#     6.trtbps : resting blood pressure (in mm Hg)
#     7.chol : cholestoral in mg/dl fetched via BMI sensor
#     8.fbs : (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
#     9.rest_ecg : resting electrocardiographic results
#         Value 0: normal
#         Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
#         Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria
#     10.thalach : maximum heart rate achieved
#     11.target :
#         0 = less chance of heart attack
#         1 = more chance of heart attack

# %%
heart.shape     #shape of the csv file
# Out:
# (303, 14)

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
heart.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
heart.describe(include = "all")
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
heart.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
heart.duplicated().sum()
# Out:
# 1

# %%
heart.drop_duplicates(inplace = True)

# %%
heart.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
list = ['sex','cp','trtbps','restecg','thall','exng','chol']
for col in list:
    print('{}:{}' .format(col.upper(),heart[col].unique()))
# Out:
# SEX:[1 0]
# CP:[3 2 1 0]
# TRTBPS:[145 130 120 140 172 150 110 135 160 105 125 142 155 104 138 128 108 134
#  122 115 118 100 124  94 112 102 152 101 132 148 178 129 180 136 126 106
#  156 170 146 117 200 165 174 192 144 123 154 114 164]
# RESTECG:[0 1 2]
# THALL:[1 2 3 0]
# EXNG:[0 1]
# CHOL:[233 250 204 236 354 192 294 263 199 168 239 275 266 211 283 219 340 226
#  247 234 243 302 212 175 417 197 198 177 273 213 304 232 269 360 308 245
#  208 264 321 325 235 257 216 256 231 141 252 201 222 260 182 303 265 309
#  186 203 183 220 209 258 227 261 221 205 240 318 298 564 277 214 248 255
#  207 223 288 160 394 315 246 244 270 195 196 254 126 313 262 215 193 271
#  268 267 210 295 306 178 242 180 228 149 278 253 342 157 286 229 284 224
#  206 167 230 335 276 353 225 330 290 172 305 188 282 185 326 274 164 307
#  249 341 407 217 174 281 289 322 299 300 293 184 409 259 200 327 237 218
#  319 166 311 169 187 176 241 131]

# %% [markdown]
# # Data Analysis

# %%
print(f'Number of people with sex 0 are {heart.sex.value_counts()[0]} and with 1 are {heart.sex.value_counts()[1]}')
# Out:
# Number of people with sex 0 are 96 and with 1 are 206

# %%
plt.subplots(figsize = (10,6))
sns.countplot(x = "sex" ,  data = heart)

# %%
print(f'Number of people with ca as 0 are {heart.cp.value_counts()[0]} and Number of people with ca as 1 are {heart.cp.value_counts()[1]} and Number of people with ca as 2 are {heart.cp.value_counts()[2]} and Number of people with ca as 3 are {heart.cp.value_counts()[3]}')
# Out:
# Number of people with ca as 0 are 143 and Number of people with ca as 1 are 50 and Number of people with ca as 2 are 86 and Number of people with ca as 3 are 23

# %%
plt.subplots(figsize = (10,6))
sns.countplot(x = "cp" ,  data = heart)

# %%
pd.crosstab(heart.output,heart.sex)
# Out:
# sex      0    1
# output
# 0       24  114
# 1       72   92

# %%
sns.countplot(x = "output",data = heart,hue = "sex")

# %%
pd.crosstab(heart.sex,heart.cp)
# Out:
# cp     0   1   2   3
# sex
# 0     39  18  35   4
# 1    104  32  51  19

# %%
sns.countplot(data = heart, x = "sex",hue = "cp")

# %%
pd.crosstab(heart.cp,heart.output)
# Out:
# output    0   1
# cp
# 0       104  39
# 1         9  41
# 2        18  68
# 3         7  16

# %%
sns.countplot(data = heart, x = "cp",hue = "output")

# %%
sns.distplot(heart["age"], bins = 30, kde = True);

# %%
plt.figure(figsize = (10,6))
plt.scatter(heart.age[heart.output == 0],
           heart.thalachh[heart.output == 0],
           color = "red")
plt.scatter(heart.age[heart.output == 1],
           heart.thalachh[heart.output == 1],
           color = "blue")
plt.title("Heart Disease w.r.t Age and Max Heart Rate")
plt.xlabel("Age")
plt.legend(["No Disease", "Disease"])
plt.ylabel("Max Heart Rate");

# %%
sns.distplot(heart.thalachh[heart.output == 1],kde = True)
plt.title("Maximum heart achieved of peple with heart disease")
plt.xlabel("Maximum heart rate achieved")
plt.ylabel("Number of people with heart disease");

# %%
sns.distplot(heart.thalachh[heart.output == 0],kde = True)
plt.title("Maximum heart achieved of people without heart disease")
plt.xlabel("Maximum heart rate achieved")
plt.ylabel("Number of people without heart disease");

# %%
plt.figure(figsize = (10,6))
plt.scatter(heart.age[heart.output == 0],
           heart.chol[heart.output == 0],
           color = "green")
plt.scatter(heart.age[heart.output == 1],
           heart.chol[heart.output == 1],
           color = "lightblue")
plt.title("Heart Disease w.r.t Age and Serum Cholestoral")
plt.xlabel("Age")
plt.legend(["No Disease", "Disease"])
plt.ylabel("Serum cholestoral")
# Out:
# Text(0, 0.5, 'Serum cholestoral')

# %%
sns.distplot(heart.chol[heart.output == 0],kde = True)
plt.title("Serum Cholestoralof people without heart disease")
plt.xlabel("Serum Cholestoral")
plt.ylabel("Number of people without heart disease");

# %%
sns.distplot(heart.thalachh[heart.output == 1],kde = True)
plt.title("Serum Cholestoralof people with heart disease")
plt.xlabel("Serum Cholestoral")
plt.ylabel("Number of people with heart disease");

# %%
sns.pairplot(heart)

# %%
plt.subplots(figsize = (20,10))
sns.heatmap(heart.corr(),annot = True,fmt = '.1f',cmap = "coolwarm")

# %%
X = heart.drop("oldpeak",axis = 1)
y = heart["trtbps"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state = 101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# -1.4210854715202004e-13

# %%
print(lm.coef_)
# Out:
# [ 6.75547070e-16  1.31245939e-14 -5.18918167e-15  1.00000000e+00
#  -2.39487047e-16 -2.80320595e-15  1.73268016e-17  1.17803006e-16
#  -1.76036180e-16  3.94241839e-17 -7.64559059e-17  1.98757586e-16
#   1.62697259e-15]

# %%
prediction = lm.predict(X_test)

# %%
from sklearn import metrics

# %%
print("MAE: ",metrics.mean_absolute_error(y_test,prediction))
print("MSE: ",metrics.mean_squared_error(y_test,prediction))
print("RMSE: ",np.sqrt(metrics.mean_absolute_error(y_test,prediction)))
# Out:
# MAE:  2.4517628464689172e-14
# MSE:  1.0408109420269843e-27
# RMSE:  1.5658106036391876e-07

# %%
plt.scatter(y_test,prediction)
